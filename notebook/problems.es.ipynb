# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
import random

# Función para lanzar un dado
def lanzar_dado():
    return random.randint(1, 6)

# Función para simular el experimento
def simular_experimento(iteraciones):
    contador_exitos = 0
    for _ in range(iteraciones):
        dado1 = lanzar_dado()
        dado2 = lanzar_dado()
        suma = dado1 + dado2
        if suma > 7 or suma % 2 == 0:
            contador_exitos += 1
    return contador_exitos / iteraciones

# Número de iteraciones
iteraciones = 1000

# Simular el experimento y calcular la probabilidad
probabilidad = simular_experimento(iteraciones)

print("La probabilidad estimada es:", probabilidad)

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
import numpy as np

# Crear la caja con las bolas
ball_box = {}
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

# Definir la función para tomar las bolas
def take_balls(n_simulations=1000):
    count_1 = 0
    count_2 = 0

    for i in range(n_simulations):
        colors = []

        # Tomar 5 bolas de la caja
        for i in range(5):
            colors.append(ball_box[np.random.randint(0, 59)])

        # Convertir la lista a un array de Numpy para un mejor filtrado
        colors = np.array(colors)
        
        white_balls = sum(colors == "White")
        red_balls = sum(colors == "Red")
        green_balls = sum(colors == "Green")

        # Decidir si se debe agregar al conteo
        if (white_balls == 3) and (red_balls == 2):
            count_1 += 1
        
        if (white_balls == 5) or (red_balls == 5) or (green_balls == 5):
            count_2 += 1
    
    return count_1 / n_simulations, count_2 / n_simulations

# Calcular las probabilidades
probabilities = take_balls(1000)

# Imprimir las probabilidades
print(f"La probabilidad de obtener 3 bolas blancas y 2 rojas es: {np.round(probabilities[0] * 100, 2)}%")
print(f"La probabilidad de obtener todas las bolas del mismo color es: {np.round(probabilities[1] * 100, 2)}%")
# Out:
# Running cells with 'c:\Program Files\Python312\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Program Files/Python312/python.exe" -m pip install ipykernel -U --user --force-reinstall'
